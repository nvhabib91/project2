# %%
import pandas as pd
import json

# %%
with open('players.json') as f:
    json_dict = json.load(f)
for key in json_dict:
    if json_dict[key] is Null:
         json_dict.pop(key)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-85113db27a02> in <module>
#       2     json_dict = json.load(f)
#       3 for key in json_dict:
# ----> 4     if json_dict[key] is Null:
#       5          json_dict.pop(key)
#
# TypeError: list indices must be integers or slices, not dict

# %%
pd.read_json("players.json")
# Out:
#                                        _id             Player Pos   Age   Tm  \
# 0     {'$oid': '5e7fb3856369ae5be3c629e6'}       Álex Abrines  SG  25.0  OKC
# 1     {'$oid': '5e7fb3856369ae5be3c629e7'}         Quincy Acy  PF  28.0  PHO
# 2     {'$oid': '5e7fb3856369ae5be3c629e8'}       Jaylen Adams  PG  22.0  ATL
# 3     {'$oid': '5e7fb3856369ae5be3c629e9'}       Steven Adams   C  25.0  OKC
# 4     {'$oid': '5e7fb3856369ae5be3c629ea'}        Bam Adebayo   C  21.0  MIA
# ...                                    ...                ...  ..   ...  ...
# 4081  {'$oid': '5e8029e9b57bbbcf08d2102b'}        Cody Zeller   C  24.0  CHO
# 4082  {'$oid': '5e8029e9b57bbbcf08d2102c'}       Tyler Zeller   C  27.0  BOS
# 4083  {'$oid': '5e8029e9b57bbbcf08d2102d'}  Stephen Zimmerman   C  20.0  ORL
# 4084  {'$oid': '5e8029e9b57bbbcf08d2102e'}        Paul Zipser  SF  22.0  CHI
# 4085  {'$oid': '5e8029e9b57bbbcf08d2102f'}        Ivica Zubac   C  19.0  LAL
#
# ...
